# %% [markdown]
# This notebook will produce a graph as follows:
# - X axis is
#     - em-var status (categorical) OR pleiotropy
#     - mean predicted activity bin
# - Y-axis is the odds ratio of phylop significance representation in that category
#
#
# Minor technical note : the operations here may produce a table that is taller than required. i.e. we may have counts divvied by a column "X" which is never used. However, the actual odds-ratio function `orc.compute_OR` performs a summation, collapsing irrelevant columns, so we can just leave the extra rows without consequence.

# %%
import glob
import pandas as pd

# %%
#importlib code just for debugging : to allow changes in scripts we are imporing from
#reflect here. It can be removed if you are not making changes to the scripts we are imporing from

import importlib ##can remove
import graphing_config as gc
import or_common as orc
importlib.reload(gc) ##can remove
importlib.reload(orc) ##can remove
# Out:
# <module 'or_common' from '/gpfs/gibbs/pi/reilly/VariantEffects/scripts/noon_scripts/5.graphs/odds_ratio/or_common.py'>

# %%
#phylop_emvar=pd.read_csv(glob.glob(GC.data_base_path+"phylop_emvar/*.csv")[0])
master_table=pd.read_csv(glob.glob("/home/mcn26/varef/scripts/noon_data/4.old.count/count_all.csv/*.csv")[0])

# %%
#fix the dumb character substitutions
#(pyspark hates certain characters, so we had to put substitutes)
#both in the actual table...
master_table.columns=[col_name.replace("&", ".").replace("^",",") for col_name in master_table.columns]

# %%
#extract some relevant sets of columns & drop all the columns we don't need...

columns=master_table.columns.to_list()

genomic_regions_cols=[i for i in columns if i.startswith("is_in_") ]
mean_activity_cols=[i for i in columns if i.startswith("mean_skew_")]
emVar_cols=[i for i in columns if i.startswith("emVar_")]

# %%
#perform the actual subsetting
#columns_to_keep is columns we would want no matter what
columns_to_keep=genomic_regions_cols+mean_activity_cols+["count","phylop_significant"]

master_table=master_table[columns_to_keep+emVar_cols+["pleio"]]

# %%
#convert pleiotropy to boolean masks
pleio_columns=[]
for i in [0,1,2,3]:
    name=f"pleio_{i}"
    pleio_columns.append(name)
    master_table[name] = master_table["pleio"]==i

# %%
#break the table into two sub-tables : one for pleiotropy analysis, and one for emvar status analysis

pleio_table=master_table[columns_to_keep+pleio_columns].copy()
emvar_table=master_table[columns_to_keep+emVar_cols].copy()

#delete the original table to free up memory
del master_table

# %%
def get_or(emvar_or_pleio):
    #not a very reusable function : just called twice to avoid code duplication. 

    #this is the return value : a list of dictionaries
    records=[]
    
    #temp lines : will change once have a function call
    table=None
    inner_cols=None
    
    if emvar_or_pleio=="emvar":
        table=emvar_table
        inner_cols=emVar_cols
    elif emvar_or_pleio=="pleio":
        table=pleio_table
        inner_cols=pleio_columns
    else:
        print("valid values for `emvar_or_pleio` are `emvar` and `pleio` :^) ")
        exit(-1)
    
    
    

    #select one combo of subset cata
    for genome_region in genomic_regions_cols+["all"]:


        for mean_activity_strata in mean_activity_cols:


            #subset the table to whatever we have selected   
            
            #only the mean activity strata of interest (boolean mask)
            selected=table[table[mean_activity_strata]]
            
            #only the genomic region of interest (boolean mask)
            if genome_region!="all":
                selected=selected[selected[genome_region]]
            
            
            

            #the location of this subsetting code is very particular : the innermost loop *besides*
            #the cata loop
            #I can't "subset as I go" because this would result in `selected` being re-subset inconsistently
            #I could put the subsetting code in the innermost loop, but `cata` does not involve performing a subset
            #So that would be slower than required.

            for cata in inner_cols:

                #note that we don't have to 

                stats=orc.compute_OR(df=selected,
                              a=cata,
                              a_val=True,
                              b="phylop_significant",
                              b_val=True)

                #build a dictionary of all the information in the current record and append it to the return list

                to_app={"mean_activity_strata":mean_activity_strata,
                     "genome_region":genome_region,emvar_or_pleio:cata}
                to_app.update(stats)

                records.append(to_app)


    return records
#get_or(emvar_or_pleio="pleio")
get_or(emvar_or_pleio="emvar")
# Out:
# [{'mean_activity_strata': 'mean_skew_(-Inf, -1.5)',
#   'genome_region': 'is_in_dELS',
#   'emvar': 'emVar_K562',
#   'OR': 1.3715766231536959,
#   'ci_lower': 1.0452874519886601,
#   'ci_upper': 1.7997177997331433,
#   'p': 0.020942491308712997},
#  {'mean_activity_strata': 'mean_skew_(-Inf, -1.5)',
#   'genome_region': 'is_in_dELS',
#   'emvar': 'emVar_SKNSH',
#   'OR': 0.7809148430628667,
#   'ci_lower': 0.47463416264180447,
#   'ci_upper': 1.2848379659854465,
#   'p': 0.32215385877954383},
#  {'mean_activity_strata': 'mean_skew_(-Inf, -1.5)',
#   'genome_region': 'is_in_dELS',
#   'emvar': 'emVar_HepG2',
#   'OR': 1.3721178954386355,
#   'ci_lower': 0.33114095219376777,
#   'ci_upper': 5.685517017784258,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_[-1.5, -1.0)',
#   'genome_region': 'is_in_dELS',
#   'emvar': 'emVar_K562',
#   'OR': 1.1887162133335365,
#   'ci_lower': 1.0898765650644404,
#   'ci_upper': 1.2965195152704962,
#   'p': 7.243196815372367e-05},
#  {'mean_activity_strata': 'mean_skew_[-1.5, -1.0)',
#   'genome_region': 'is_in_dELS',
#   'emvar': 'emVar_SKNSH',
#   'OR': 0.7275837483862279,
#   'ci_lower': 0.6768063123777789,
#   'ci_upper': 0.7821707647139469,
#   'p': 7.901415538957567e-17},
#  {'mean_activity_strata': 'mean_skew_[-1.5, -1.0)',
#   'genome_region': 'is_in_dELS',
#   'emvar': 'emVar_HepG2',
#   'OR': 0.8876570705936995,
#   'ci_lower': 0.7953455714191332,
#   'ci_upper': 0.9906826708911918,
#   'p': 0.03457386496364952},
#  {'mean_activity_strata': 'mean_skew_[-1.0, -0.5)',
#   'genome_region': 'is_in_dELS',
#   'emvar': 'emVar_K562',
#   'OR': 1.1046365706357295,
#   'ci_lower': 1.0813388210601507,
#   'ci_upper': 1.128436276790241,
#   'p': 3.7893911732442345e-20},
#  {'mean_activity_strata': 'mean_skew_[-1.0, -0.5)',
#   'genome_region': 'is_in_dELS',
#   'emvar': 'emVar_SKNSH',
#   'OR': 0.9243513286452505,
#   'ci_lower': 0.9058644971293939,
#   'ci_upper': 0.9432154383749886,
#   'p': 2.6153299670537916e-14},
#  {'mean_activity_strata': 'mean_skew_[-1.0, -0.5)',
#   'genome_region': 'is_in_dELS',
#   'emvar': 'emVar_HepG2',
#   'OR': 1.0661982854742107,
#   'ci_lower': 1.044722543679605,
#   'ci_upper': 1.0881154913574576,
#   'p': 6.319404716839198e-10},
#  {'mean_activity_strata': 'mean_skew_[-0.5, -0.2)',
#   'genome_region': 'is_in_dELS',
#   'emvar': 'emVar_K562',
#   'OR': 1.1532019986426716,
#   'ci_lower': 1.1345449681032673,
#   'ci_upper': 1.172165834816347,
#   'p': 7.859905550507858e-64},
#  {'mean_activity_strata': 'mean_skew_[-0.5, -0.2)',
#   'genome_region': 'is_in_dELS',
#   'emvar': 'emVar_SKNSH',
#   'OR': 1.2623724881092604,
#   'ci_lower': 1.2361010848417457,
#   'ci_upper': 1.2892022491341688,
#   'p': 7.363742588925165e-99},
#  {'mean_activity_strata': 'mean_skew_[-0.5, -0.2)',
#   'genome_region': 'is_in_dELS',
#   'emvar': 'emVar_HepG2',
#   'OR': 1.5315714375959593,
#   'ci_lower': 1.4939254674671902,
#   'ci_upper': 1.5701660621909639,
#   'p': 2.6616054608327017e-222},
#  {'mean_activity_strata': 'mean_skew_[-0.2, -0.05)',
#   'genome_region': 'is_in_dELS',
#   'emvar': 'emVar_K562',
#   'OR': 1.2994735303918261,
#   'ci_lower': 1.2409067870597286,
#   'ci_upper': 1.3608044325312543,
#   'p': 7.596260177836064e-27},
#  {'mean_activity_strata': 'mean_skew_[-0.2, -0.05)',
#   'genome_region': 'is_in_dELS',
#   'emvar': 'emVar_SKNSH',
#   'OR': 1.6610246313800254,
#   'ci_lower': 1.4509665934977825,
#   'ci_upper': 1.9014930036398292,
#   'p': 5.807858405645572e-12},
#  {'mean_activity_strata': 'mean_skew_[-0.2, -0.05)',
#   'genome_region': 'is_in_dELS',
#   'emvar': 'emVar_HepG2',
#   'OR': 2.1285774458255844,
#   'ci_lower': 1.9914761494503366,
#   'ci_upper': 2.2751173515826024,
#   'p': 3.3971188101727362e-90},
#  {'mean_activity_strata': 'mean_skew_[-0.05, -0.02)',
#   'genome_region': 'is_in_dELS',
#   'emvar': 'emVar_K562',
#   'OR': 1.1591289030209362,
#   'ci_lower': 0.8760243922386527,
#   'ci_upper': 1.5337242041686112,
#   'p': 0.28561761893684157},
#  {'mean_activity_strata': 'mean_skew_[-0.05, -0.02)',
#   'genome_region': 'is_in_dELS',
#   'emvar': 'emVar_SKNSH',
#   'OR': 1.3911812972570405,
#   'ci_lower': 0.8084538969816935,
#   'ci_upper': 2.393934161321269,
#   'p': 0.25808364250702287},
#  {'mean_activity_strata': 'mean_skew_[-0.05, -0.02)',
#   'genome_region': 'is_in_dELS',
#   'emvar': 'emVar_HepG2',
#   'OR': 2.558019328852974,
#   'ci_lower': 1.6216966237598678,
#   'ci_upper': 4.034948825147422,
#   'p': 0.00034413660419266615},
#  {'mean_activity_strata': 'mean_skew_[-0.02, 0)',
#   'genome_region': 'is_in_dELS',
#   'emvar': 'emVar_K562',
#   'OR': 1.009501377681145,
#   'ci_lower': 0.6945431737440741,
#   'ci_upper': 1.467285361177052,
#   'p': 0.9236209773165818},
#  {'mean_activity_strata': 'mean_skew_[-0.02, 0)',
#   'genome_region': 'is_in_dELS',
#   'emvar': 'emVar_SKNSH',
#   'OR': 1.3058114895092476,
#   'ci_lower': 0.663907450954149,
#   'ci_upper': 2.568345397666159,
#   'p': 0.4331367689589073},
#  {'mean_activity_strata': 'mean_skew_[-0.02, 0)',
#   'genome_region': 'is_in_dELS',
#   'emvar': 'emVar_HepG2',
#   'OR': 1.3950981177892259,
#   'ci_lower': 0.67966843011797,
#   'ci_upper': 2.863600355722307,
#   'p': 0.38935105592147395},
#  {'mean_activity_strata': 'mean_skew_[0, 0.02)',
#   'genome_region': 'is_in_dELS',
#   'emvar': 'emVar_K562',
#   'OR': 0.8232970760421442,
#   'ci_lower': 0.5468772527060787,
#   'ci_upper': 1.2394336609642091,
#   'p': 0.3902068319886437},
#  {'mean_activity_strata': 'mean_skew_[0, 0.02)',
#   'genome_region': 'is_in_dELS',
#   'emvar': 'emVar_SKNSH',
#   'OR': 1.1504445916603379,
#   'ci_lower': 0.5358719666569545,
#   'ci_upper': 2.469848846054289,
#   'p': 0.6758879044251517},
#  {'mean_activity_strata': 'mean_skew_[0, 0.02)',
#   'genome_region': 'is_in_dELS',
#   'emvar': 'emVar_HepG2',
#   'OR': 2.4739166227358775,
#   'ci_lower': 1.3856914296815404,
#   'ci_upper': 4.416757818625931,
#   'p': 0.0043626811111876305},
#  {'mean_activity_strata': 'mean_skew_[0.02, 0.05)',
#   'genome_region': 'is_in_dELS',
#   'emvar': 'emVar_K562',
#   'OR': 0.7895724949679985,
#   'ci_lower': 0.5818230077084696,
#   'ci_upper': 1.0715023581920045,
#   'p': 0.14119301365202175},
#  {'mean_activity_strata': 'mean_skew_[0.02, 0.05)',
#   'genome_region': 'is_in_dELS',
#   'emvar': 'emVar_SKNSH',
#   'OR': 1.2438244921168715,
#   'ci_lower': 0.7091411870286725,
#   'ci_upper': 2.181652110311342,
#   'p': 0.4277550927331299},
#  {'mean_activity_strata': 'mean_skew_[0.02, 0.05)',
#   'genome_region': 'is_in_dELS',
#   'emvar': 'emVar_HepG2',
#   'OR': 1.2046293366834355,
#   'ci_lower': 0.6543905583349371,
#   'ci_upper': 2.217531748151599,
#   'p': 0.49837716914084645},
#  {'mean_activity_strata': 'mean_skew_[0.05, 0.2)',
#   'genome_region': 'is_in_dELS',
#   'emvar': 'emVar_K562',
#   'OR': 0.9884287402858425,
#   'ci_lower': 0.9405076652557899,
#   'ci_upper': 1.0387915066671416,
#   'p': 0.6588940989018885},
#  {'mean_activity_strata': 'mean_skew_[0.05, 0.2)',
#   'genome_region': 'is_in_dELS',
#   'emvar': 'emVar_SKNSH',
#   'OR': 1.448678523604845,
#   'ci_lower': 1.2345938316940428,
#   'ci_upper': 1.699886562590575,
#   'p': 1.476083803011856e-05},
#  {'mean_activity_strata': 'mean_skew_[0.05, 0.2)',
#   'genome_region': 'is_in_dELS',
#   'emvar': 'emVar_HepG2',
#   'OR': 1.416483054244179,
#   'ci_lower': 1.2933066212193967,
#   'ci_upper': 1.55139099270145,
#   'p': 8.354774199123284e-13},
#  {'mean_activity_strata': 'mean_skew_[0.2, 0.5)',
#   'genome_region': 'is_in_dELS',
#   'emvar': 'emVar_K562',
#   'OR': 0.9609532642589877,
#   'ci_lower': 0.9418240767336251,
#   'ci_upper': 0.9804709806236743,
#   'p': 9.805326905072025e-05},
#  {'mean_activity_strata': 'mean_skew_[0.2, 0.5)',
#   'genome_region': 'is_in_dELS',
#   'emvar': 'emVar_SKNSH',
#   'OR': 1.1707868951695846,
#   'ci_lower': 1.142832413131892,
#   'ci_upper': 1.199425163436138,
#   'p': 4.510454532103273e-36},
#  {'mean_activity_strata': 'mean_skew_[0.2, 0.5)',
#   'genome_region': 'is_in_dELS',
#   'emvar': 'emVar_HepG2',
#   'OR': 1.1732674367209401,
#   'ci_lower': 1.1370241387617228,
#   'ci_upper': 1.2106660106344493,
#   'p': 1.488970124955902e-22},
#  {'mean_activity_strata': 'mean_skew_[0.5, 1.0)',
#   'genome_region': 'is_in_dELS',
#   'emvar': 'emVar_K562',
#   'OR': 0.9323363098176001,
#   'ci_lower': 0.9077573143296676,
#   'ci_upper': 0.957580821308168,
#   'p': 2.9198752003992777e-07},
#  {'mean_activity_strata': 'mean_skew_[0.5, 1.0)',
#   'genome_region': 'is_in_dELS',
#   'emvar': 'emVar_SKNSH',
#   'OR': 1.1071894720646516,
#   'ci_lower': 1.077281210802609,
#   'ci_upper': 1.1379280681387642,
#   'p': 2.610269878220256e-13},
#  {'mean_activity_strata': 'mean_skew_[0.5, 1.0)',
#   'genome_region': 'is_in_dELS',
#   'emvar': 'emVar_HepG2',
#   'OR': 0.9985305291023686,
#   'ci_lower': 0.9720085753641952,
#   'ci_upper': 1.0257761534417262,
#   'p': 0.9179419692809265},
#  {'mean_activity_strata': 'mean_skew_[1.0, 1.5)',
#   'genome_region': 'is_in_dELS',
#   'emvar': 'emVar_K562',
#   'OR': 0.9614525474276914,
#   'ci_lower': 0.861738039699316,
#   'ci_upper': 1.0727053447446075,
#   'p': 0.47866323637034935},
#  {'mean_activity_strata': 'mean_skew_[1.0, 1.5)',
#   'genome_region': 'is_in_dELS',
#   'emvar': 'emVar_SKNSH',
#   'OR': 1.3453056889096955,
#   'ci_lower': 1.1650746840705166,
#   'ci_upper': 1.5534174944816226,
#   'p': 2.9799592289052504e-05},
#  {'mean_activity_strata': 'mean_skew_[1.0, 1.5)',
#   'genome_region': 'is_in_dELS',
#   'emvar': 'emVar_HepG2',
#   'OR': 1.3343108342914825,
#   'ci_lower': 1.080256001233745,
#   'ci_upper': 1.6481143363001725,
#   'p': 0.006562322053761073},
#  {'mean_activity_strata': 'mean_skew_(1.5, Inf)',
#   'genome_region': 'is_in_dELS',
#   'emvar': 'emVar_K562',
#   'OR': 1.1604631600810011,
#   'ci_lower': 0.772782075795779,
#   'ci_upper': 1.7426319632458263,
#   'p': 0.5585341900914486},
#  {'mean_activity_strata': 'mean_skew_(1.5, Inf)',
#   'genome_region': 'is_in_dELS',
#   'emvar': 'emVar_SKNSH',
#   'OR': 2.198990774249452,
#   'ci_lower': 0.6970181800326642,
#   'ci_upper': 6.937495410819263,
#   'p': 0.2177998104671086},
#  {'mean_activity_strata': 'mean_skew_(1.5, Inf)',
#   'genome_region': 'is_in_dELS',
#   'emvar': 'emVar_HepG2',
#   'OR': inf,
#   'ci_lower': nan,
#   'ci_upper': inf,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_(-Inf, -1.5)',
#   'genome_region': 'is_in_CA',
#   'emvar': 'emVar_K562',
#   'OR': 0.9549330085261876,
#   'ci_lower': 0.13049013109025392,
#   'ci_upper': 6.988245342034021,
#   'p': 0.6210445030447778},
#  {'mean_activity_strata': 'mean_skew_(-Inf, -1.5)',
#   'genome_region': 'is_in_CA',
#   'emvar': 'emVar_SKNSH',
#   'OR': inf,
#   'ci_lower': nan,
#   'ci_upper': inf,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_(-Inf, -1.5)',
#   'genome_region': 'is_in_CA',
#   'emvar': 'emVar_HepG2',
#   'OR': inf,
#   'ci_lower': nan,
#   'ci_upper': inf,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_[-1.5, -1.0)',
#   'genome_region': 'is_in_CA',
#   'emvar': 'emVar_K562',
#   'OR': 0.6652256493940772,
#   'ci_lower': 0.4492924741051646,
#   'ci_upper': 0.9849378525494535,
#   'p': 0.04610155602049719},
#  {'mean_activity_strata': 'mean_skew_[-1.5, -1.0)',
#   'genome_region': 'is_in_CA',
#   'emvar': 'emVar_SKNSH',
#   'OR': 0.6106319982140969,
#   'ci_lower': 0.40443137005594954,
#   'ci_upper': 0.9219646764576084,
#   'p': 0.02844454228808429},
#  {'mean_activity_strata': 'mean_skew_[-1.5, -1.0)',
#   'genome_region': 'is_in_CA',
#   'emvar': 'emVar_HepG2',
#   'OR': 0.622896701582349,
#   'ci_lower': 0.3726973979625002,
#   'ci_upper': 1.0410598597235432,
#   'p': 0.07597025952349407},
#  {'mean_activity_strata': 'mean_skew_[-1.0, -0.5)',
#   'genome_region': 'is_in_CA',
#   'emvar': 'emVar_K562',
#   'OR': 0.731794098593122,
#   'ci_lower': 0.6549457574361476,
#   'ci_upper': 0.8176594727967675,
#   'p': 4.092876390219659e-08},
#  {'mean_activity_strata': 'mean_skew_[-1.0, -0.5)',
#   'genome_region': 'is_in_CA',
#   'emvar': 'emVar_SKNSH',
#   'OR': 0.7890033486066269,
#   'ci_lower': 0.7062281796782346,
#   'ci_upper': 0.8814803798909585,
#   'p': 3.112648649275541e-05},
#  {'mean_activity_strata': 'mean_skew_[-1.0, -0.5)',
#   'genome_region': 'is_in_CA',
#   'emvar': 'emVar_HepG2',
#   'OR': 0.749498322635989,
#   'ci_lower': 0.6709849793319331,
#   'ci_upper': 0.8371986749889184,
#   'p': 3.3498854332248145e-07},
#  {'mean_activity_strata': 'mean_skew_[-0.5, -0.2)',
#   'genome_region': 'is_in_CA',
#   'emvar': 'emVar_K562',
#   'OR': 0.8613349163194901,
#   'ci_lower': 0.7950585843451796,
#   'ci_upper': 0.9331360640324883,
#   'p': 0.00021002034690343035},
#  {'mean_activity_strata': 'mean_skew_[-0.5, -0.2)',
#   'genome_region': 'is_in_CA',
#   'emvar': 'emVar_SKNSH',
#   'OR': 0.9303374819923009,
#   'ci_lower': 0.8384658940683904,
#   'ci_upper': 1.0322755362177882,
#   'p': 0.180936374752361},
#  {'mean_activity_strata': 'mean_skew_[-0.5, -0.2)',
#   'genome_region': 'is_in_CA',
#   'emvar': 'emVar_HepG2',
#   'OR': 0.9644676573149253,
#   'ci_lower': 0.834603568395351,
#   'ci_upper': 1.114538563254628,
#   'p': 0.6630765452414827},
#  {'mean_activity_strata': 'mean_skew_[-0.2, -0.05)',
#   'genome_region': 'is_in_CA',
#   'emvar': 'emVar_K562',
#   'OR': 0.7784520541223969,
#   'ci_lower': 0.6377215769209896,
#   'ci_upper': 0.9502385092459525,
#   'p': 0.012832695558210875},
#  {'mean_activity_strata': 'mean_skew_[-0.2, -0.05)',
#   'genome_region': 'is_in_CA',
#   'emvar': 'emVar_SKNSH',
#   'OR': 0.6078918695754207,
#   'ci_lower': 0.271164720346943,
#   'ci_upper': 1.3627603348367006,
#   'p': 0.32557121190524685},
#  {'mean_activity_strata': 'mean_skew_[-0.2, -0.05)',
#   'genome_region': 'is_in_CA',
#   'emvar': 'emVar_HepG2',
#   'OR': 1.3395072030728445,
#   'ci_lower': 0.955497749781385,
#   'ci_upper': 1.8778480090555527,
#   'p': 0.0924795600936022},
#  {'mean_activity_strata': 'mean_skew_[-0.05, -0.02)',
#   'genome_region': 'is_in_CA',
#   'emvar': 'emVar_K562',
#   'OR': 0.2163206677956644,
#   'ci_lower': 0.030229922885555875,
#   'ci_upper': 1.5479573498323773,
#   'p': 0.14041568290980333},
#  {'mean_activity_strata': 'mean_skew_[-0.05, -0.02)',
#   'genome_region': 'is_in_CA',
#   'emvar': 'emVar_SKNSH',
#   'OR': 0.0,
#   'ci_lower': 0.0,
#   'ci_upper': nan,
#   'p': 0.6254471719313489},
#  {'mean_activity_strata': 'mean_skew_[-0.05, -0.02)',
#   'genome_region': 'is_in_CA',
#   'emvar': 'emVar_HepG2',
#   'OR': 0.0,
#   'ci_lower': 0.0,
#   'ci_upper': nan,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_[-0.02, 0)',
#   'genome_region': 'is_in_CA',
#   'emvar': 'emVar_K562',
#   'OR': 0.6492773026432439,
#   'ci_lower': 0.1594646221841821,
#   'ci_upper': 2.643602135405196,
#   'p': 0.7715844039782426},
#  {'mean_activity_strata': 'mean_skew_[-0.02, 0)',
#   'genome_region': 'is_in_CA',
#   'emvar': 'emVar_SKNSH',
#   'OR': 0.0,
#   'ci_lower': 0.0,
#   'ci_upper': nan,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_[-0.02, 0)',
#   'genome_region': 'is_in_CA',
#   'emvar': 'emVar_HepG2',
#   'OR': 6.168274231678487,
#   'ci_lower': 0.6894245351050768,
#   'ci_upper': 55.18748617118753,
#   'p': 0.18016566423881888},
#  {'mean_activity_strata': 'mean_skew_[0, 0.02)',
#   'genome_region': 'is_in_CA',
#   'emvar': 'emVar_K562',
#   'OR': 0.0,
#   'ci_lower': 0.0,
#   'ci_upper': nan,
#   'p': 0.18357856556073512},
#  {'mean_activity_strata': 'mean_skew_[0, 0.02)',
#   'genome_region': 'is_in_CA',
#   'emvar': 'emVar_SKNSH',
#   'OR': 0.0,
#   'ci_lower': 0.0,
#   'ci_upper': nan,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_[0, 0.02)',
#   'genome_region': 'is_in_CA',
#   'emvar': 'emVar_HepG2',
#   'OR': 0.0,
#   'ci_lower': 0.0,
#   'ci_upper': nan,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_[0.02, 0.05)',
#   'genome_region': 'is_in_CA',
#   'emvar': 'emVar_K562',
#   'OR': 0.0,
#   'ci_lower': 0.0,
#   'ci_upper': nan,
#   'p': 0.02565426276729714},
#  {'mean_activity_strata': 'mean_skew_[0.02, 0.05)',
#   'genome_region': 'is_in_CA',
#   'emvar': 'emVar_SKNSH',
#   'OR': 0.0,
#   'ci_lower': 0.0,
#   'ci_upper': nan,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_[0.02, 0.05)',
#   'genome_region': 'is_in_CA',
#   'emvar': 'emVar_HepG2',
#   'OR': 0.0,
#   'ci_lower': 0.0,
#   'ci_upper': nan,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_[0.05, 0.2)',
#   'genome_region': 'is_in_CA',
#   'emvar': 'emVar_K562',
#   'OR': 0.6526656525189368,
#   'ci_lower': 0.5325211263101098,
#   'ci_upper': 0.7999165346351115,
#   'p': 1.4310062908879373e-05},
#  {'mean_activity_strata': 'mean_skew_[0.05, 0.2)',
#   'genome_region': 'is_in_CA',
#   'emvar': 'emVar_SKNSH',
#   'OR': 0.5494223170028936,
#   'ci_lower': 0.2268494301034889,
#   'ci_upper': 1.3306838914389914,
#   'p': 0.23192213982354287},
#  {'mean_activity_strata': 'mean_skew_[0.05, 0.2)',
#   'genome_region': 'is_in_CA',
#   'emvar': 'emVar_HepG2',
#   'OR': 0.8944407621411058,
#   'ci_lower': 0.5959138833970511,
#   'ci_upper': 1.3425165938725319,
#   'p': 0.6935391356780984},
#  {'mean_activity_strata': 'mean_skew_[0.2, 0.5)',
#   'genome_region': 'is_in_CA',
#   'emvar': 'emVar_K562',
#   'OR': 0.6988368557758212,
#   'ci_lower': 0.6399968760817208,
#   'ci_upper': 0.763086460641217,
#   'p': 6.604167926009334e-17},
#  {'mean_activity_strata': 'mean_skew_[0.2, 0.5)',
#   'genome_region': 'is_in_CA',
#   'emvar': 'emVar_SKNSH',
#   'OR': 0.9279350131506424,
#   'ci_lower': 0.8386205853250644,
#   'ci_upper': 1.0267615697712922,
#   'p': 0.15378107064673596},
#  {'mean_activity_strata': 'mean_skew_[0.2, 0.5)',
#   'genome_region': 'is_in_CA',
#   'emvar': 'emVar_HepG2',
#   'OR': 1.101163077326755,
#   'ci_lower': 0.968642804946665,
#   'ci_upper': 1.251813482405926,
#   'p': 0.1420688814650778},
#  {'mean_activity_strata': 'mean_skew_[0.5, 1.0)',
#   'genome_region': 'is_in_CA',
#   'emvar': 'emVar_K562',
#   'OR': 0.7156981336728799,
#   'ci_lower': 0.6438694315004864,
#   'ci_upper': 0.7955398928462044,
#   'p': 6.558887327679019e-10},
#  {'mean_activity_strata': 'mean_skew_[0.5, 1.0)',
#   'genome_region': 'is_in_CA',
#   'emvar': 'emVar_SKNSH',
#   'OR': 0.7740045562288145,
#   'ci_lower': 0.696195760761702,
#   'ci_upper': 0.8605094814244664,
#   'p': 2.583507960185271e-06},
#  {'mean_activity_strata': 'mean_skew_[0.5, 1.0)',
#   'genome_region': 'is_in_CA',
#   'emvar': 'emVar_HepG2',
#   'OR': 0.7264878889037774,
#   'ci_lower': 0.6535778551875415,
#   'ci_upper': 0.8075314188428577,
#   'p': 3.6770263176482612e-09},
#  {'mean_activity_strata': 'mean_skew_[1.0, 1.5)',
#   'genome_region': 'is_in_CA',
#   'emvar': 'emVar_K562',
#   'OR': 0.677284104133786,
#   'ci_lower': 0.45449162046729075,
#   'ci_upper': 1.009289802176492,
#   'p': 0.06049527948718447},
#  {'mean_activity_strata': 'mean_skew_[1.0, 1.5)',
#   'genome_region': 'is_in_CA',
#   'emvar': 'emVar_SKNSH',
#   'OR': 0.7384886798000588,
#   'ci_lower': 0.45749598702851174,
#   'ci_upper': 1.1920662599360592,
#   'p': 0.21361407104707733},
#  {'mean_activity_strata': 'mean_skew_[1.0, 1.5)',
#   'genome_region': 'is_in_CA',
#   'emvar': 'emVar_HepG2',
#   'OR': 1.1279591616415539,
#   'ci_lower': 0.5269590815543417,
#   'ci_upper': 2.4144035369469465,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_(1.5, Inf)',
#   'genome_region': 'is_in_CA',
#   'emvar': 'emVar_K562',
#   'OR': inf,
#   'ci_lower': nan,
#   'ci_upper': inf,
#   'p': 0.262030321375857},
#  {'mean_activity_strata': 'mean_skew_(1.5, Inf)',
#   'genome_region': 'is_in_CA',
#   'emvar': 'emVar_SKNSH',
#   'OR': inf,
#   'ci_lower': nan,
#   'ci_upper': inf,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_(1.5, Inf)',
#   'genome_region': 'is_in_CA',
#   'emvar': 'emVar_HepG2',
#   'OR': inf,
#   'ci_lower': nan,
#   'ci_upper': inf,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_(-Inf, -1.5)',
#   'genome_region': 'is_in_pELS',
#   'emvar': 'emVar_K562',
#   'OR': 2.864079441201001,
#   'ci_lower': 1.3919467569285575,
#   'ci_upper': 5.893150010716435,
#   'p': 0.0017117940920969182},
#  {'mean_activity_strata': 'mean_skew_(-Inf, -1.5)',
#   'genome_region': 'is_in_pELS',
#   'emvar': 'emVar_SKNSH',
#   'OR': inf,
#   'ci_lower': nan,
#   'ci_upper': inf,
#   'p': 0.14898863358518522},
#  {'mean_activity_strata': 'mean_skew_(-Inf, -1.5)',
#   'genome_region': 'is_in_pELS',
#   'emvar': 'emVar_HepG2',
#   'OR': inf,
#   'ci_lower': nan,
#   'ci_upper': inf,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_[-1.5, -1.0)',
#   'genome_region': 'is_in_pELS',
#   'emvar': 'emVar_K562',
#   'OR': 2.118666176622305,
#   'ci_lower': 1.7129563908345857,
#   'ci_upper': 2.6204673930877895,
#   'p': 3.8419550700442454e-14},
#  {'mean_activity_strata': 'mean_skew_[-1.5, -1.0)',
#   'genome_region': 'is_in_pELS',
#   'emvar': 'emVar_SKNSH',
#   'OR': 1.996446746108052,
#   'ci_lower': 1.6232564582160276,
#   'ci_upper': 2.4554343153058236,
#   'p': 1.1707150557502517e-12},
#  {'mean_activity_strata': 'mean_skew_[-1.5, -1.0)',
#   'genome_region': 'is_in_pELS',
#   'emvar': 'emVar_HepG2',
#   'OR': 2.031723811684519,
#   'ci_lower': 1.447163038449413,
#   'ci_upper': 2.852409533198679,
#   'p': 9.554015209937908e-06},
#  {'mean_activity_strata': 'mean_skew_[-1.0, -0.5)',
#   'genome_region': 'is_in_pELS',
#   'emvar': 'emVar_K562',
#   'OR': 1.7091136980125725,
#   'ci_lower': 1.635239313020394,
#   'ci_upper': 1.7863254689852117,
#   'p': 1.6808303207054222e-135},
#  {'mean_activity_strata': 'mean_skew_[-1.0, -0.5)',
#   'genome_region': 'is_in_pELS',
#   'emvar': 'emVar_SKNSH',
#   'OR': 1.2958055422910244,
#   'ci_lower': 1.2484602546559838,
#   'ci_upper': 1.3449463025916024,
#   'p': 3.381993913100288e-43},
#  {'mean_activity_strata': 'mean_skew_[-1.0, -0.5)',
#   'genome_region': 'is_in_pELS',
#   'emvar': 'emVar_HepG2',
#   'OR': 1.283677455352037,
#   'ci_lower': 1.2372606340780588,
#   'ci_upper': 1.3318356407637222,
#   'p': 5.350325781468504e-41},
#  {'mean_activity_strata': 'mean_skew_[-0.5, -0.2)',
#   'genome_region': 'is_in_pELS',
#   'emvar': 'emVar_K562',
#   'OR': 1.3579923103813551,
#   'ci_lower': 1.3215313791612622,
#   'ci_upper': 1.3954591953959619,
#   'p': 3.2432002687816563e-102},
#  {'mean_activity_strata': 'mean_skew_[-0.5, -0.2)',
#   'genome_region': 'is_in_pELS',
#   'emvar': 'emVar_SKNSH',
#   'OR': 1.2833198338652216,
#   'ci_lower': 1.2328390432245842,
#   'ci_upper': 1.335867650398419,
#   'p': 1.9541357863362858e-32},
#  {'mean_activity_strata': 'mean_skew_[-0.5, -0.2)',
#   'genome_region': 'is_in_pELS',
#   'emvar': 'emVar_HepG2',
#   'OR': 1.2916398197321828,
#   'ci_lower': 1.2219998895183986,
#   'ci_upper': 1.3652484245111438,
#   'p': 1.5362278301976414e-18},
#  {'mean_activity_strata': 'mean_skew_[-0.2, -0.05)',
#   'genome_region': 'is_in_pELS',
#   'emvar': 'emVar_K562',
#   'OR': 1.0977516456667995,
#   'ci_lower': 0.9754883145533058,
#   'ci_upper': 1.235338914455357,
#   'p': 0.12429595794527235},
#  {'mean_activity_strata': 'mean_skew_[-0.2, -0.05)',
#   'genome_region': 'is_in_pELS',
#   'emvar': 'emVar_SKNSH',
#   'OR': 1.9268598605276448,
#   'ci_lower': 1.4118895649406291,
#   'ci_upper': 2.6296595812497134,
#   'p': 0.00015104104740314324},
#  {'mean_activity_strata': 'mean_skew_[-0.2, -0.05)',
#   'genome_region': 'is_in_pELS',
#   'emvar': 'emVar_HepG2',
#   'OR': 2.294632231807295,
#   'ci_lower': 1.9400493929433724,
#   'ci_upper': 2.7140221781985407,
#   'p': 1.4964423773181983e-18},
#  {'mean_activity_strata': 'mean_skew_[-0.05, -0.02)',
#   'genome_region': 'is_in_pELS',
#   'emvar': 'emVar_K562',
#   'OR': 1.840685795512268,
#   'ci_lower': 1.0158847292249369,
#   'ci_upper': 3.3351463018698775,
#   'p': 0.04819979236472595},
#  {'mean_activity_strata': 'mean_skew_[-0.05, -0.02)',
#   'genome_region': 'is_in_pELS',
#   'emvar': 'emVar_SKNSH',
#   'OR': 3.558549541555753,
#   'ci_lower': 1.216300879073569,
#   'ci_upper': 10.411301231116443,
#   'p': 0.03628815838631495},
#  {'mean_activity_strata': 'mean_skew_[-0.05, -0.02)',
#   'genome_region': 'is_in_pELS',
#   'emvar': 'emVar_HepG2',
#   'OR': 2.9654268114741815,
#   'ci_lower': 0.8734966792847599,
#   'ci_upper': 10.067303497261689,
#   'p': 0.09807207919733277},
#  {'mean_activity_strata': 'mean_skew_[-0.02, 0)',
#   'genome_region': 'is_in_pELS',
#   'emvar': 'emVar_K562',
#   'OR': 1.852553334662546,
#   'ci_lower': 0.8003776242321348,
#   'ci_upper': 4.28791829489469,
#   'p': 0.15269359069266808},
#  {'mean_activity_strata': 'mean_skew_[-0.02, 0)',
#   'genome_region': 'is_in_pELS',
#   'emvar': 'emVar_SKNSH',
#   'OR': 1.6108757414145443,
#   'ci_lower': 0.37978722862135605,
#   'ci_upper': 6.832564285264491,
#   'p': 0.36881345559263756},
#  {'mean_activity_strata': 'mean_skew_[-0.02, 0)',
#   'genome_region': 'is_in_pELS',
#   'emvar': 'emVar_HepG2',
#   'OR': 1.5437548804598846,
#   'ci_lower': 0.3648407801049933,
#   'ci_upper': 6.532107321604469,
#   'p': 0.3873819107508174},
#  {'mean_activity_strata': 'mean_skew_[0, 0.02)',
#   'genome_region': 'is_in_pELS',
#   'emvar': 'emVar_K562',
#   'OR': 0.8837261499919031,
#   'ci_lower': 0.32410853733520417,
#   'ci_upper': 2.409599927853192,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_[0, 0.02)',
#   'genome_region': 'is_in_pELS',
#   'emvar': 'emVar_SKNSH',
#   'OR': 0.0,
#   'ci_lower': 0.0,
#   'ci_upper': nan,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_[0, 0.02)',
#   'genome_region': 'is_in_pELS',
#   'emvar': 'emVar_HepG2',
#   'OR': 3.093114211653706,
#   'ci_lower': 0.6922655136662468,
#   'ci_upper': 13.820355539112866,
#   'p': 0.15855931670929257},
#  {'mean_activity_strata': 'mean_skew_[0.02, 0.05)',
#   'genome_region': 'is_in_pELS',
#   'emvar': 'emVar_K562',
#   'OR': 2.232239068747164,
#   'ci_lower': 1.3669483876478679,
#   'ci_upper': 3.6452665697315414,
#   'p': 0.003997620565461452},
#  {'mean_activity_strata': 'mean_skew_[0.02, 0.05)',
#   'genome_region': 'is_in_pELS',
#   'emvar': 'emVar_SKNSH',
#   'OR': 2.2010146786548397,
#   'ci_lower': 0.6627682399510837,
#   'ci_upper': 7.309441405960579,
#   'p': 0.1750825367496927},
#  {'mean_activity_strata': 'mean_skew_[0.02, 0.05)',
#   'genome_region': 'is_in_pELS',
#   'emvar': 'emVar_HepG2',
#   'OR': 0.0,
#   'ci_lower': 0.0,
#   'ci_upper': nan,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_[0.05, 0.2)',
#   'genome_region': 'is_in_pELS',
#   'emvar': 'emVar_K562',
#   'OR': 1.0491001049875195,
#   'ci_lower': 0.9337377644528599,
#   'ci_upper': 1.1787153440556692,
#   'p': 0.41266931170752574},
#  {'mean_activity_strata': 'mean_skew_[0.05, 0.2)',
#   'genome_region': 'is_in_pELS',
#   'emvar': 'emVar_SKNSH',
#   'OR': 2.12119041196551,
#   'ci_lower': 1.540832011838824,
#   'ci_upper': 2.9201423187234945,
#   'p': 2.0122342300270517e-05},
#  {'mean_activity_strata': 'mean_skew_[0.05, 0.2)',
#   'genome_region': 'is_in_pELS',
#   'emvar': 'emVar_HepG2',
#   'OR': 1.3573131306905861,
#   'ci_lower': 1.066181484212559,
#   'ci_upper': 1.7279412201626554,
#   'p': 0.016767379663980397},
#  {'mean_activity_strata': 'mean_skew_[0.2, 0.5)',
#   'genome_region': 'is_in_pELS',
#   'emvar': 'emVar_K562',
#   'OR': 1.1087747100927978,
#   'ci_lower': 1.0694125451037573,
#   'ci_upper': 1.1495856892365985,
#   'p': 2.999352803643876e-08},
#  {'mean_activity_strata': 'mean_skew_[0.2, 0.5)',
#   'genome_region': 'is_in_pELS',
#   'emvar': 'emVar_SKNSH',
#   'OR': 1.3725043771688874,
#   'ci_lower': 1.3123455797962325,
#   'ci_upper': 1.435420893969291,
#   'p': 8.412040384811998e-41},
#  {'mean_activity_strata': 'mean_skew_[0.2, 0.5)',
#   'genome_region': 'is_in_pELS',
#   'emvar': 'emVar_HepG2',
#   'OR': 0.9356562521940581,
#   'ci_lower': 0.8700446168942904,
#   'ci_upper': 1.0062157793641031,
#   'p': 0.07368094116555357},
#  {'mean_activity_strata': 'mean_skew_[0.5, 1.0)',
#   'genome_region': 'is_in_pELS',
#   'emvar': 'emVar_K562',
#   'OR': 1.3473218547961892,
#   'ci_lower': 1.2773006066811616,
#   'ci_upper': 1.4211816473869183,
#   'p': 8.155774943847574e-29},
#  {'mean_activity_strata': 'mean_skew_[0.5, 1.0)',
#   'genome_region': 'is_in_pELS',
#   'emvar': 'emVar_SKNSH',
#   'OR': 1.4383862571672308,
#   'ci_lower': 1.3627610589368386,
#   'ci_upper': 1.5182082076968468,
#   'p': 2.1583047367249928e-41},
#  {'mean_activity_strata': 'mean_skew_[0.5, 1.0)',
#   'genome_region': 'is_in_pELS',
#   'emvar': 'emVar_HepG2',
#   'OR': 1.0027805809732864,
#   'ci_lower': 0.9540066244768796,
#   'ci_upper': 1.0540481248005127,
#   'p': 0.918976507645012},
#  {'mean_activity_strata': 'mean_skew_[1.0, 1.5)',
#   'genome_region': 'is_in_pELS',
#   'emvar': 'emVar_K562',
#   'OR': 1.459567334557356,
#   'ci_lower': 1.0982313263092978,
#   'ci_upper': 1.939788779533405,
#   'p': 0.008193062089974145},
#  {'mean_activity_strata': 'mean_skew_[1.0, 1.5)',
#   'genome_region': 'is_in_pELS',
#   'emvar': 'emVar_SKNSH',
#   'OR': 1.651318007146228,
#   'ci_lower': 1.168049559973667,
#   'ci_upper': 2.3345337853531354,
#   'p': 0.002952072908709878},
#  {'mean_activity_strata': 'mean_skew_[1.0, 1.5)',
#   'genome_region': 'is_in_pELS',
#   'emvar': 'emVar_HepG2',
#   'OR': 2.0238414914838114,
#   'ci_lower': 1.1300169726720943,
#   'ci_upper': 3.624666249893547,
#   'p': 0.014388339499892478},
#  {'mean_activity_strata': 'mean_skew_(1.5, Inf)',
#   'genome_region': 'is_in_pELS',
#   'emvar': 'emVar_K562',
#   'OR': 3.5027580772261624,
#   'ci_lower': 0.8555998914243325,
#   'ci_upper': 14.340013679931833,
#   'p': 0.06164523796139529},
#  {'mean_activity_strata': 'mean_skew_(1.5, Inf)',
#   'genome_region': 'is_in_pELS',
#   'emvar': 'emVar_SKNSH',
#   'OR': 0.7898681829930214,
#   'ci_lower': 0.09852935748558712,
#   'ci_upper': 6.3320391244402465,
#   'p': 0.572030568347501},
#  {'mean_activity_strata': 'mean_skew_(1.5, Inf)',
#   'genome_region': 'is_in_pELS',
#   'emvar': 'emVar_HepG2',
#   'OR': inf,
#   'ci_lower': nan,
#   'ci_upper': inf,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_(-Inf, -1.5)',
#   'genome_region': 'is_in_CA-H3K4me3',
#   'emvar': 'emVar_K562',
#   'OR': inf,
#   'ci_lower': nan,
#   'ci_upper': inf,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_(-Inf, -1.5)',
#   'genome_region': 'is_in_CA-H3K4me3',
#   'emvar': 'emVar_SKNSH',
#   'OR': inf,
#   'ci_lower': nan,
#   'ci_upper': inf,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_(-Inf, -1.5)',
#   'genome_region': 'is_in_CA-H3K4me3',
#   'emvar': 'emVar_HepG2',
#   'OR': inf,
#   'ci_lower': nan,
#   'ci_upper': inf,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_[-1.5, -1.0)',
#   'genome_region': 'is_in_CA-H3K4me3',
#   'emvar': 'emVar_K562',
#   'OR': 1.8439724367711645,
#   'ci_lower': 0.8150323806959989,
#   'ci_upper': 4.171900930694494,
#   'p': 0.1542099529064298},
#  {'mean_activity_strata': 'mean_skew_[-1.5, -1.0)',
#   'genome_region': 'is_in_CA-H3K4me3',
#   'emvar': 'emVar_SKNSH',
#   'OR': 0.25709245552236143,
#   'ci_lower': 0.1812480312525666,
#   'ci_upper': 0.3646744752466459,
#   'p': 2.24009297669076e-11},
#  {'mean_activity_strata': 'mean_skew_[-1.5, -1.0)',
#   'genome_region': 'is_in_CA-H3K4me3',
#   'emvar': 'emVar_HepG2',
#   'OR': 0.5597017679843502,
#   'ci_lower': 0.2833646280016042,
#   'ci_upper': 1.1055228427559207,
#   'p': 0.10939936672146842},
#  {'mean_activity_strata': 'mean_skew_[-1.0, -0.5)',
#   'genome_region': 'is_in_CA-H3K4me3',
#   'emvar': 'emVar_K562',
#   'OR': 1.5452835648148149,
#   'ci_lower': 1.3441677039867324,
#   'ci_upper': 1.7764906035194787,
#   'p': 2.4407420099860233e-10},
#  {'mean_activity_strata': 'mean_skew_[-1.0, -0.5)',
#   'genome_region': 'is_in_CA-H3K4me3',
#   'emvar': 'emVar_SKNSH',
#   'OR': 0.42627288208604913,
#   'ci_lower': 0.380044024653943,
#   'ci_upper': 0.47812505450494924,
#   'p': 2.2741152257753416e-48},
#  {'mean_activity_strata': 'mean_skew_[-1.0, -0.5)',
#   'genome_region': 'is_in_CA-H3K4me3',
#   'emvar': 'emVar_HepG2',
#   'OR': 0.8503998406942411,
#   'ci_lower': 0.7581690456813066,
#   'ci_upper': 0.9538504548189858,
#   'p': 0.006298751045342249},
#  {'mean_activity_strata': 'mean_skew_[-0.5, -0.2)',
#   'genome_region': 'is_in_CA-H3K4me3',
#   'emvar': 'emVar_K562',
#   'OR': 1.3074769318256871,
#   'ci_lower': 1.1897554339780199,
#   'ci_upper': 1.4368464967127812,
#   'p': 6.320631514641041e-08},
#  {'mean_activity_strata': 'mean_skew_[-0.5, -0.2)',
#   'genome_region': 'is_in_CA-H3K4me3',
#   'emvar': 'emVar_SKNSH',
#   'OR': 0.7733395493195582,
#   'ci_lower': 0.6650324862573079,
#   'ci_upper': 0.8992854798831348,
#   'p': 0.0006171724435979374},
#  {'mean_activity_strata': 'mean_skew_[-0.5, -0.2)',
#   'genome_region': 'is_in_CA-H3K4me3',
#   'emvar': 'emVar_HepG2',
#   'OR': 1.2664201642301804,
#   'ci_lower': 1.0468854758816144,
#   'ci_upper': 1.5319918647435347,
#   'p': 0.017475179582163387},
#  {'mean_activity_strata': 'mean_skew_[-0.2, -0.05)',
#   'genome_region': 'is_in_CA-H3K4me3',
#   'emvar': 'emVar_K562',
#   'OR': 0.8626189905769382,
#   'ci_lower': 0.6252025523289598,
#   'ci_upper': 1.1901927145563702,
#   'p': 0.4000335334378634},
#  {'mean_activity_strata': 'mean_skew_[-0.2, -0.05)',
#   'genome_region': 'is_in_CA-H3K4me3',
#   'emvar': 'emVar_SKNSH',
#   'OR': 0.23188714466931903,
#   'ci_lower': 0.03246819986074372,
#   'ci_upper': 1.6561327111917692,
#   'p': 0.13699293774925245},
#  {'mean_activity_strata': 'mean_skew_[-0.2, -0.05)',
#   'genome_region': 'is_in_CA-H3K4me3',
#   'emvar': 'emVar_HepG2',
#   'OR': 1.3892883297049732,
#   'ci_lower': 0.7986348729508561,
#   'ci_upper': 2.4167765876825213,
#   'p': 0.24471805108265965},
#  {'mean_activity_strata': 'mean_skew_[-0.05, -0.02)',
#   'genome_region': 'is_in_CA-H3K4me3',
#   'emvar': 'emVar_K562',
#   'OR': 0.48883330370185873,
#   'ci_lower': 0.06776239357948302,
#   'ci_upper': 3.5264102429880073,
#   'p': 0.7248634306149855},
#  {'mean_activity_strata': 'mean_skew_[-0.05, -0.02)',
#   'genome_region': 'is_in_CA-H3K4me3',
#   'emvar': 'emVar_SKNSH',
#   'OR': 0.0,
#   'ci_lower': 0.0,
#   'ci_upper': nan,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_[-0.05, -0.02)',
#   'genome_region': 'is_in_CA-H3K4me3',
#   'emvar': 'emVar_HepG2',
#   'OR': 4.260218615908555,
#   'ci_lower': 0.5241294900513747,
#   'ci_upper': 34.627821940633055,
#   'p': 0.23192991529284238},
#  {'mean_activity_strata': 'mean_skew_[-0.02, 0)',
#   'genome_region': 'is_in_CA-H3K4me3',
#   'emvar': 'emVar_K562',
#   'OR': 0.0,
#   'ci_lower': 0.0,
#   'ci_upper': nan,
#   'p': 0.6272854137162986},
#  {'mean_activity_strata': 'mean_skew_[-0.02, 0)',
#   'genome_region': 'is_in_CA-H3K4me3',
#   'emvar': 'emVar_SKNSH',
#   'OR': 0.0,
#   'ci_lower': 0.0,
#   'ci_upper': nan,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_[-0.02, 0)',
#   'genome_region': 'is_in_CA-H3K4me3',
#   'emvar': 'emVar_HepG2',
#   'OR': 0.0,
#   'ci_lower': 0.0,
#   'ci_upper': nan,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_[0, 0.02)',
#   'genome_region': 'is_in_CA-H3K4me3',
#   'emvar': 'emVar_K562',
#   'OR': 0.0,
#   'ci_lower': 0.0,
#   'ci_upper': nan,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_[0, 0.02)',
#   'genome_region': 'is_in_CA-H3K4me3',
#   'emvar': 'emVar_SKNSH',
#   'OR': 0.0,
#   'ci_lower': 0.0,
#   'ci_upper': nan,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_[0, 0.02)',
#   'genome_region': 'is_in_CA-H3K4me3',
#   'emvar': 'emVar_HepG2',
#   'OR': nan,
#   'ci_lower': 0,
#   'ci_upper': inf,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_[0.02, 0.05)',
#   'genome_region': 'is_in_CA-H3K4me3',
#   'emvar': 'emVar_K562',
#   'OR': 0.0,
#   'ci_lower': 0.0,
#   'ci_upper': nan,
#   'p': 0.26620875939566246},
#  {'mean_activity_strata': 'mean_skew_[0.02, 0.05)',
#   'genome_region': 'is_in_CA-H3K4me3',
#   'emvar': 'emVar_SKNSH',
#   'OR': 0.0,
#   'ci_lower': 0.0,
#   'ci_upper': nan,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_[0.02, 0.05)',
#   'genome_region': 'is_in_CA-H3K4me3',
#   'emvar': 'emVar_HepG2',
#   'OR': 3.4463863383416804,
#   'ci_lower': 0.4310315919561575,
#   'ci_upper': 27.556167609905277,
#   'p': 0.2743307506521869},
#  {'mean_activity_strata': 'mean_skew_[0.05, 0.2)',
#   'genome_region': 'is_in_CA-H3K4me3',
#   'emvar': 'emVar_K562',
#   'OR': 0.767769217930128,
#   'ci_lower': 0.5515337422847879,
#   'ci_upper': 1.0687824276337097,
#   'p': 0.13538213998488838},
#  {'mean_activity_strata': 'mean_skew_[0.05, 0.2)',
#   'genome_region': 'is_in_CA-H3K4me3',
#   'emvar': 'emVar_SKNSH',
#   'OR': 0.8509942845937793,
#   'ci_lower': 0.2704762360612745,
#   'ci_upper': 2.6774672812557836,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_[0.05, 0.2)',
#   'genome_region': 'is_in_CA-H3K4me3',
#   'emvar': 'emVar_HepG2',
#   'OR': 1.186891097763583,
#   'ci_lower': 0.650275209506552,
#   'ci_upper': 2.1663296668181675,
#   'p': 0.506324725289655},
#  {'mean_activity_strata': 'mean_skew_[0.2, 0.5)',
#   'genome_region': 'is_in_CA-H3K4me3',
#   'emvar': 'emVar_K562',
#   'OR': 0.8542047390892377,
#   'ci_lower': 0.7514738178246342,
#   'ci_upper': 0.9709795856823707,
#   'p': 0.014952560738529515},
#  {'mean_activity_strata': 'mean_skew_[0.2, 0.5)',
#   'genome_region': 'is_in_CA-H3K4me3',
#   'emvar': 'emVar_SKNSH',
#   'OR': 0.906483538000526,
#   'ci_lower': 0.7750696788084043,
#   'ci_upper': 1.0601787518371966,
#   'p': 0.23417516458584842},
#  {'mean_activity_strata': 'mean_skew_[0.2, 0.5)',
#   'genome_region': 'is_in_CA-H3K4me3',
#   'emvar': 'emVar_HepG2',
#   'OR': 1.0514775529649143,
#   'ci_lower': 0.8468696102140882,
#   'ci_upper': 1.305519800279039,
#   'p': 0.6512738321671705},
#  {'mean_activity_strata': 'mean_skew_[0.5, 1.0)',
#   'genome_region': 'is_in_CA-H3K4me3',
#   'emvar': 'emVar_K562',
#   'OR': 0.6375871227291023,
#   'ci_lower': 0.5401857479883682,
#   'ci_upper': 0.7525510263531221,
#   'p': 1.5656942004215328e-07},
#  {'mean_activity_strata': 'mean_skew_[0.5, 1.0)',
#   'genome_region': 'is_in_CA-H3K4me3',
#   'emvar': 'emVar_SKNSH',
#   'OR': 0.7526222350120774,
#   'ci_lower': 0.6358167103830864,
#   'ci_upper': 0.8908860358408768,
#   'p': 0.0011236137507323759},
#  {'mean_activity_strata': 'mean_skew_[0.5, 1.0)',
#   'genome_region': 'is_in_CA-H3K4me3',
#   'emvar': 'emVar_HepG2',
#   'OR': 0.7067996968413615,
#   'ci_lower': 0.5988077932957325,
#   'ci_upper': 0.8342673843730694,
#   'p': 5.205093321730025e-05},
#  {'mean_activity_strata': 'mean_skew_[1.0, 1.5)',
#   'genome_region': 'is_in_CA-H3K4me3',
#   'emvar': 'emVar_K562',
#   'OR': 0.5930432516935904,
#   'ci_lower': 0.30406856150649675,
#   'ci_upper': 1.1566480159501553,
#   'p': 0.1385120499886666},
#  {'mean_activity_strata': 'mean_skew_[1.0, 1.5)',
#   'genome_region': 'is_in_CA-H3K4me3',
#   'emvar': 'emVar_SKNSH',
#   'OR': 0.8108744010951403,
#   'ci_lower': 0.350470052448783,
#   'ci_upper': 1.8761012239340784,
#   'p': 0.6360576105127794},
#  {'mean_activity_strata': 'mean_skew_[1.0, 1.5)',
#   'genome_region': 'is_in_CA-H3K4me3',
#   'emvar': 'emVar_HepG2',
#   'OR': 0.5467272274763564,
#   'ci_lower': 0.19684699985604937,
#   'ci_upper': 1.5184923391393899,
#   'p': 0.2888478298284417},
#  {'mean_activity_strata': 'mean_skew_(1.5, Inf)',
#   'genome_region': 'is_in_CA-H3K4me3',
#   'emvar': 'emVar_K562',
#   'OR': inf,
#   'ci_lower': nan,
#   'ci_upper': inf,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_(1.5, Inf)',
#   'genome_region': 'is_in_CA-H3K4me3',
#   'emvar': 'emVar_SKNSH',
#   'OR': inf,
#   'ci_lower': nan,
#   'ci_upper': inf,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_(1.5, Inf)',
#   'genome_region': 'is_in_CA-H3K4me3',
#   'emvar': 'emVar_HepG2',
#   'OR': inf,
#   'ci_lower': nan,
#   'ci_upper': inf,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_(-Inf, -1.5)',
#   'genome_region': 'is_in_CA-CTCF',
#   'emvar': 'emVar_K562',
#   'OR': inf,
#   'ci_lower': nan,
#   'ci_upper': inf,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_(-Inf, -1.5)',
#   'genome_region': 'is_in_CA-CTCF',
#   'emvar': 'emVar_SKNSH',
#   'OR': 0.16177096636866753,
#   'ci_lower': 0.020200702803331066,
#   'ci_upper': 1.2954918358353946,
#   'p': 0.16535610809162088},
#  {'mean_activity_strata': 'mean_skew_(-Inf, -1.5)',
#   'genome_region': 'is_in_CA-CTCF',
#   'emvar': 'emVar_HepG2',
#   'OR': inf,
#   'ci_lower': nan,
#   'ci_upper': inf,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_[-1.5, -1.0)',
#   'genome_region': 'is_in_CA-CTCF',
#   'emvar': 'emVar_K562',
#   'OR': 2.0278416002162456,
#   'ci_lower': 1.1046887691529856,
#   'ci_upper': 3.722443524722847,
#   'p': 0.01590931939459591},
#  {'mean_activity_strata': 'mean_skew_[-1.5, -1.0)',
#   'genome_region': 'is_in_CA-CTCF',
#   'emvar': 'emVar_SKNSH',
#   'OR': 0.2571628415875668,
#   'ci_lower': 0.20544078912731487,
#   'ci_upper': 0.3219065083147072,
#   'p': 1.5458874084407023e-28},
#  {'mean_activity_strata': 'mean_skew_[-1.5, -1.0)',
#   'genome_region': 'is_in_CA-CTCF',
#   'emvar': 'emVar_HepG2',
#   'OR': 0.5714815305176751,
#   'ci_lower': 0.37497487780154815,
#   'ci_upper': 0.8709680542803448,
#   'p': 0.01468886574074815},
#  {'mean_activity_strata': 'mean_skew_[-1.0, -0.5)',
#   'genome_region': 'is_in_CA-CTCF',
#   'emvar': 'emVar_K562',
#   'OR': 1.9496677190548328,
#   'ci_lower': 1.748916080728184,
#   'ci_upper': 2.1734628988840865,
#   'p': 2.298062540414599e-37},
#  {'mean_activity_strata': 'mean_skew_[-1.0, -0.5)',
#   'genome_region': 'is_in_CA-CTCF',
#   'emvar': 'emVar_SKNSH',
#   'OR': 0.4099768292443617,
#   'ci_lower': 0.3725804527284505,
#   'ci_upper': 0.4511267278956359,
#   'p': 3.20888287982916e-82},
#  {'mean_activity_strata': 'mean_skew_[-1.0, -0.5)',
#   'genome_region': 'is_in_CA-CTCF',
#   'emvar': 'emVar_HepG2',
#   'OR': 0.8507683738990414,
#   'ci_lower': 0.7811012029664344,
#   'ci_upper': 0.9266492271142008,
#   'p': 0.00022308213548577938},
#  {'mean_activity_strata': 'mean_skew_[-0.5, -0.2)',
#   'genome_region': 'is_in_CA-CTCF',
#   'emvar': 'emVar_K562',
#   'OR': 1.4457972004342323,
#   'ci_lower': 1.3447942516766482,
#   'ci_upper': 1.554386139126714,
#   'p': 6.629176132791177e-22},
#  {'mean_activity_strata': 'mean_skew_[-0.5, -0.2)',
#   'genome_region': 'is_in_CA-CTCF',
#   'emvar': 'emVar_SKNSH',
#   'OR': 0.7073046225861627,
#   'ci_lower': 0.6111320164200876,
#   'ci_upper': 0.8186117167650816,
#   'p': 1.2136008543378711e-06},
#  {'mean_activity_strata': 'mean_skew_[-0.5, -0.2)',
#   'genome_region': 'is_in_CA-CTCF',
#   'emvar': 'emVar_HepG2',
#   'OR': 0.8460525399860865,
#   'ci_lower': 0.7057901319543599,
#   'ci_upper': 1.0141894424548235,
#   'p': 0.07142622119726091},
#  {'mean_activity_strata': 'mean_skew_[-0.2, -0.05)',
#   'genome_region': 'is_in_CA-CTCF',
#   'emvar': 'emVar_K562',
#   'OR': 0.9891947706537695,
#   'ci_lower': 0.7650037220512983,
#   'ci_upper': 1.2790869718450188,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_[-0.2, -0.05)',
#   'genome_region': 'is_in_CA-CTCF',
#   'emvar': 'emVar_SKNSH',
#   'OR': 0.96943203648921,
#   'ci_lower': 0.358792836563524,
#   'ci_upper': 2.619334550747716,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_[-0.2, -0.05)',
#   'genome_region': 'is_in_CA-CTCF',
#   'emvar': 'emVar_HepG2',
#   'OR': 0.6414061354211198,
#   'ci_lower': 0.3316467478092436,
#   'ci_upper': 1.2404820287653955,
#   'p': 0.21922961909024202},
#  {'mean_activity_strata': 'mean_skew_[-0.05, -0.02)',
#   'genome_region': 'is_in_CA-CTCF',
#   'emvar': 'emVar_K562',
#   'OR': 0.0,
#   'ci_lower': 0.0,
#   'ci_upper': nan,
#   'p': 0.26547872367042946},
#  {'mean_activity_strata': 'mean_skew_[-0.05, -0.02)',
#   'genome_region': 'is_in_CA-CTCF',
#   'emvar': 'emVar_SKNSH',
#   'OR': 0.0,
#   'ci_lower': 0.0,
#   'ci_upper': nan,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_[-0.05, -0.02)',
#   'genome_region': 'is_in_CA-CTCF',
#   'emvar': 'emVar_HepG2',
#   'OR': 0.0,
#   'ci_lower': 0.0,
#   'ci_upper': nan,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_[-0.02, 0)',
#   'genome_region': 'is_in_CA-CTCF',
#   'emvar': 'emVar_K562',
#   'OR': 0.0,
#   'ci_lower': 0.0,
#   'ci_upper': nan,
#   'p': 0.6315682269656048},
#  {'mean_activity_strata': 'mean_skew_[-0.02, 0)',
#   'genome_region': 'is_in_CA-CTCF',
#   'emvar': 'emVar_SKNSH',
#   'OR': 0.0,
#   'ci_lower': 0.0,
#   'ci_upper': nan,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_[-0.02, 0)',
#   'genome_region': 'is_in_CA-CTCF',
#   'emvar': 'emVar_HepG2',
#   'OR': 3.7461662400117772,
#   'ci_lower': 0.46089552226827957,
#   'ci_upper': 30.448899630739213,
#   'p': 0.2587430722448042},
#  {'mean_activity_strata': 'mean_skew_[0, 0.02)',
#   'genome_region': 'is_in_CA-CTCF',
#   'emvar': 'emVar_K562',
#   'OR': 0.0,
#   'ci_lower': 0.0,
#   'ci_upper': nan,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_[0, 0.02)',
#   'genome_region': 'is_in_CA-CTCF',
#   'emvar': 'emVar_SKNSH',
#   'OR': 0.0,
#   'ci_lower': 0.0,
#   'ci_upper': nan,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_[0, 0.02)',
#   'genome_region': 'is_in_CA-CTCF',
#   'emvar': 'emVar_HepG2',
#   'OR': 0.0,
#   'ci_lower': 0.0,
#   'ci_upper': nan,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_[0.02, 0.05)',
#   'genome_region': 'is_in_CA-CTCF',
#   'emvar': 'emVar_K562',
#   'OR': 1.0169208378741708,
#   'ci_lower': 0.24793215062356544,
#   'ci_upper': 4.171012060766652,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_[0.02, 0.05)',
#   'genome_region': 'is_in_CA-CTCF',
#   'emvar': 'emVar_SKNSH',
#   'OR': 2.2881097402259356,
#   'ci_lower': 0.2975123215950746,
#   'ci_upper': 17.597409597181105,
#   'p': 0.3718996218550497},
#  {'mean_activity_strata': 'mean_skew_[0.02, 0.05)',
#   'genome_region': 'is_in_CA-CTCF',
#   'emvar': 'emVar_HepG2',
#   'OR': 0.0,
#   'ci_lower': 0.0,
#   'ci_upper': nan,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_[0.05, 0.2)',
#   'genome_region': 'is_in_CA-CTCF',
#   'emvar': 'emVar_K562',
#   'OR': 0.8157340073776702,
#   'ci_lower': 0.6208493184716999,
#   'ci_upper': 1.0717930277034922,
#   'p': 0.1631637520337902},
#  {'mean_activity_strata': 'mean_skew_[0.05, 0.2)',
#   'genome_region': 'is_in_CA-CTCF',
#   'emvar': 'emVar_SKNSH',
#   'OR': 0.6729431337585913,
#   'ci_lower': 0.21440415033262888,
#   'ci_upper': 2.1121441006168635,
#   'p': 0.805837776205208},
#  {'mean_activity_strata': 'mean_skew_[0.05, 0.2)',
#   'genome_region': 'is_in_CA-CTCF',
#   'emvar': 'emVar_HepG2',
#   'OR': 0.9275581877338724,
#   'ci_lower': 0.5342136656442487,
#   'ci_upper': 1.610524490410719,
#   'p': 0.8922956264240038},
#  {'mean_activity_strata': 'mean_skew_[0.2, 0.5)',
#   'genome_region': 'is_in_CA-CTCF',
#   'emvar': 'emVar_K562',
#   'OR': 0.9041736348213179,
#   'ci_lower': 0.8121453941857726,
#   'ci_upper': 1.0066300538780002,
#   'p': 0.06877338420089896},
#  {'mean_activity_strata': 'mean_skew_[0.2, 0.5)',
#   'genome_region': 'is_in_CA-CTCF',
#   'emvar': 'emVar_SKNSH',
#   'OR': 0.8729511029926129,
#   'ci_lower': 0.7533540493542937,
#   'ci_upper': 1.0115345220075125,
#   'p': 0.07032615246822055},
#  {'mean_activity_strata': 'mean_skew_[0.2, 0.5)',
#   'genome_region': 'is_in_CA-CTCF',
#   'emvar': 'emVar_HepG2',
#   'OR': 1.047676781217096,
#   'ci_lower': 0.8704977675890198,
#   'ci_upper': 1.2609183834456736,
#   'p': 0.5958035270113079},
#  {'mean_activity_strata': 'mean_skew_[0.5, 1.0)',
#   'genome_region': 'is_in_CA-CTCF',
#   'emvar': 'emVar_K562',
#   'OR': 0.8527734129562128,
#   'ci_lower': 0.7387715373640726,
#   'ci_upper': 0.984367232716772,
#   'p': 0.03161309450016592},
#  {'mean_activity_strata': 'mean_skew_[0.5, 1.0)',
#   'genome_region': 'is_in_CA-CTCF',
#   'emvar': 'emVar_SKNSH',
#   'OR': 0.7251239366939045,
#   'ci_lower': 0.6287912654527236,
#   'ci_upper': 0.8362150564987436,
#   'p': 1.0814696769865785e-05},
#  {'mean_activity_strata': 'mean_skew_[0.5, 1.0)',
#   'genome_region': 'is_in_CA-CTCF',
#   'emvar': 'emVar_HepG2',
#   'OR': 0.8363897418401001,
#   'ci_lower': 0.7251902334457994,
#   'ci_upper': 0.9646404046720155,
#   'p': 0.015407579166555599},
#  {'mean_activity_strata': 'mean_skew_[1.0, 1.5)',
#   'genome_region': 'is_in_CA-CTCF',
#   'emvar': 'emVar_K562',
#   'OR': 0.5326722944303006,
#   'ci_lower': 0.3139013214052704,
#   'ci_upper': 0.9039139178624589,
#   'p': 0.026656612947281517},
#  {'mean_activity_strata': 'mean_skew_[1.0, 1.5)',
#   'genome_region': 'is_in_CA-CTCF',
#   'emvar': 'emVar_SKNSH',
#   'OR': 1.2327433628318585,
#   'ci_lower': 0.5952512165719943,
#   'ci_upper': 2.552966136478614,
#   'p': 0.7320262384878594},
#  {'mean_activity_strata': 'mean_skew_[1.0, 1.5)',
#   'genome_region': 'is_in_CA-CTCF',
#   'emvar': 'emVar_HepG2',
#   'OR': 2.204022988505747,
#   'ci_lower': 0.5395912914586195,
#   'ci_upper': 9.002586607227213,
#   'p': 0.44545686112480637},
#  {'mean_activity_strata': 'mean_skew_(1.5, Inf)',
#   'genome_region': 'is_in_CA-CTCF',
#   'emvar': 'emVar_K562',
#   'OR': 0.28386844166014097,
#   'ci_lower': 0.06419665415282275,
#   'ci_upper': 1.2552257315269086,
#   'p': 0.1282910376820858},
#  {'mean_activity_strata': 'mean_skew_(1.5, Inf)',
#   'genome_region': 'is_in_CA-CTCF',
#   'emvar': 'emVar_SKNSH',
#   'OR': inf,
#   'ci_lower': nan,
#   'ci_upper': inf,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_(1.5, Inf)',
#   'genome_region': 'is_in_CA-CTCF',
#   'emvar': 'emVar_HepG2',
#   'OR': inf,
#   'ci_lower': nan,
#   'ci_upper': inf,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_(-Inf, -1.5)',
#   'genome_region': 'is_in_PLS',
#   'emvar': 'emVar_K562',
#   'OR': 4.5490331491712706,
#   'ci_lower': 1.5587538029879107,
#   'ci_upper': 13.275799265151544,
#   'p': 0.0021056535182230524},
#  {'mean_activity_strata': 'mean_skew_(-Inf, -1.5)',
#   'genome_region': 'is_in_PLS',
#   'emvar': 'emVar_SKNSH',
#   'OR': inf,
#   'ci_lower': nan,
#   'ci_upper': inf,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_(-Inf, -1.5)',
#   'genome_region': 'is_in_PLS',
#   'emvar': 'emVar_HepG2',
#   'OR': nan,
#   'ci_lower': 0,
#   'ci_upper': inf,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_[-1.5, -1.0)',
#   'genome_region': 'is_in_PLS',
#   'emvar': 'emVar_K562',
#   'OR': 2.947866584480515,
#   'ci_lower': 1.9849143064944053,
#   'ci_upper': 4.37798114077995,
#   'p': 5.508470011452358e-09},
#  {'mean_activity_strata': 'mean_skew_[-1.5, -1.0)',
#   'genome_region': 'is_in_PLS',
#   'emvar': 'emVar_SKNSH',
#   'OR': 2.1967073516889015,
#   'ci_lower': 1.5805536948847716,
#   'ci_upper': 3.053058687332901,
#   'p': 1.1915607358557522e-06},
#  {'mean_activity_strata': 'mean_skew_[-1.5, -1.0)',
#   'genome_region': 'is_in_PLS',
#   'emvar': 'emVar_HepG2',
#   'OR': 1.8004852556924225,
#   'ci_lower': 1.0392734373581385,
# ...
#   'p': 0.7571364685824997},
#  {'mean_activity_strata': 'mean_skew_[-0.5, -0.2)',
#   'genome_region': 'is_in_CA-TF',
#   'emvar': 'emVar_HepG2',
#   'OR': 1.466616463348366,
#   'ci_lower': 1.1688539777073583,
#   'ci_upper': 1.8402331613598681,
#   'p': 0.0017206229896288927},
#  {'mean_activity_strata': 'mean_skew_[-0.2, -0.05)',
#   'genome_region': 'is_in_CA-TF',
#   'emvar': 'emVar_K562',
#   'OR': 0.5208981496643197,
#   'ci_lower': 0.3224585777148408,
#   'ci_upper': 0.8414565500058152,
#   'p': 0.005148278635094084},
#  {'mean_activity_strata': 'mean_skew_[-0.2, -0.05)',
#   'genome_region': 'is_in_CA-TF',
#   'emvar': 'emVar_SKNSH',
#   'OR': 0.0,
#   'ci_lower': 0.0,
#   'ci_upper': nan,
#   'p': 0.4102146391162363},
#  {'mean_activity_strata': 'mean_skew_[-0.2, -0.05)',
#   'genome_region': 'is_in_CA-TF',
#   'emvar': 'emVar_HepG2',
#   'OR': 1.582868424032889,
#   'ci_lower': 0.9429083976904948,
#   'ci_upper': 2.6571748156418167,
#   'p': 0.09804424899110184},
#  {'mean_activity_strata': 'mean_skew_[-0.05, -0.02)',
#   'genome_region': 'is_in_CA-TF',
#   'emvar': 'emVar_K562',
#   'OR': 3.0521593891672634,
#   'ci_lower': 0.708066945959967,
#   'ci_upper': 13.15649175552473,
#   'p': 0.15479626387801096},
#  {'mean_activity_strata': 'mean_skew_[-0.05, -0.02)',
#   'genome_region': 'is_in_CA-TF',
#   'emvar': 'emVar_SKNSH',
#   'OR': 0.0,
#   'ci_lower': 0.0,
#   'ci_upper': nan,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_[-0.05, -0.02)',
#   'genome_region': 'is_in_CA-TF',
#   'emvar': 'emVar_HepG2',
#   'OR': 5.493472659604924,
#   'ci_lower': 0.6417187933284526,
#   'ci_upper': 47.02720595932522,
#   'p': 0.19312463194845927},
#  {'mean_activity_strata': 'mean_skew_[-0.02, 0)',
#   'genome_region': 'is_in_CA-TF',
#   'emvar': 'emVar_K562',
#   'OR': 0.0,
#   'ci_lower': 0.0,
#   'ci_upper': nan,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_[-0.02, 0)',
#   'genome_region': 'is_in_CA-TF',
#   'emvar': 'emVar_SKNSH',
#   'OR': 0.0,
#   'ci_lower': 0.0,
#   'ci_upper': nan,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_[-0.02, 0)',
#   'genome_region': 'is_in_CA-TF',
#   'emvar': 'emVar_HepG2',
#   'OR': 0.0,
#   'ci_lower': 0.0,
#   'ci_upper': nan,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_[0, 0.02)',
#   'genome_region': 'is_in_CA-TF',
#   'emvar': 'emVar_K562',
#   'OR': 0.0,
#   'ci_lower': 0.0,
#   'ci_upper': nan,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_[0, 0.02)',
#   'genome_region': 'is_in_CA-TF',
#   'emvar': 'emVar_SKNSH',
#   'OR': 0.0,
#   'ci_lower': 0.0,
#   'ci_upper': nan,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_[0, 0.02)',
#   'genome_region': 'is_in_CA-TF',
#   'emvar': 'emVar_HepG2',
#   'OR': 0.0,
#   'ci_lower': 0.0,
#   'ci_upper': nan,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_[0.02, 0.05)',
#   'genome_region': 'is_in_CA-TF',
#   'emvar': 'emVar_K562',
#   'OR': 0.8215770697502768,
#   'ci_lower': 0.11235365263004979,
#   'ci_upper': 6.007716400302597,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_[0.02, 0.05)',
#   'genome_region': 'is_in_CA-TF',
#   'emvar': 'emVar_SKNSH',
#   'OR': 0.0,
#   'ci_lower': 0.0,
#   'ci_upper': nan,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_[0.02, 0.05)',
#   'genome_region': 'is_in_CA-TF',
#   'emvar': 'emVar_HepG2',
#   'OR': 0.0,
#   'ci_lower': 0.0,
#   'ci_upper': nan,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_[0.05, 0.2)',
#   'genome_region': 'is_in_CA-TF',
#   'emvar': 'emVar_K562',
#   'OR': 0.8563009653622565,
#   'ci_lower': 0.565458048746881,
#   'ci_upper': 1.296738714578916,
#   'p': 0.5538164701124679},
#  {'mean_activity_strata': 'mean_skew_[0.05, 0.2)',
#   'genome_region': 'is_in_CA-TF',
#   'emvar': 'emVar_SKNSH',
#   'OR': 0.780405819295559,
#   'ci_lower': 0.10726997566182479,
#   'ci_upper': 5.67757416772786,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_[0.05, 0.2)',
#   'genome_region': 'is_in_CA-TF',
#   'emvar': 'emVar_HepG2',
#   'OR': 0.6604815325513962,
#   'ci_lower': 0.24527122899949474,
#   'ci_upper': 1.778585513763376,
#   'p': 0.5344251270558459},
#  {'mean_activity_strata': 'mean_skew_[0.2, 0.5)',
#   'genome_region': 'is_in_CA-TF',
#   'emvar': 'emVar_K562',
#   'OR': 0.7904834347132818,
#   'ci_lower': 0.6447199591708656,
#   'ci_upper': 0.9692022895641483,
#   'p': 0.024645282608154274},
#  {'mean_activity_strata': 'mean_skew_[0.2, 0.5)',
#   'genome_region': 'is_in_CA-TF',
#   'emvar': 'emVar_SKNSH',
#   'OR': 0.6710649991909446,
#   'ci_lower': 0.49457103989086865,
#   'ci_upper': 0.9105430702907945,
#   'p': 0.008480597423860235},
#  {'mean_activity_strata': 'mean_skew_[0.2, 0.5)',
#   'genome_region': 'is_in_CA-TF',
#   'emvar': 'emVar_HepG2',
#   'OR': 1.0430658975032066,
#   'ci_lower': 0.7624235531334155,
#   'ci_upper': 1.427010566584352,
#   'p': 0.744939113668189},
#  {'mean_activity_strata': 'mean_skew_[0.5, 1.0)',
#   'genome_region': 'is_in_CA-TF',
#   'emvar': 'emVar_K562',
#   'OR': 0.7819672131147541,
#   'ci_lower': 0.5926716773002281,
#   'ci_upper': 1.031722530038673,
#   'p': 0.08276852714081862},
#  {'mean_activity_strata': 'mean_skew_[0.5, 1.0)',
#   'genome_region': 'is_in_CA-TF',
#   'emvar': 'emVar_SKNSH',
#   'OR': 0.6775483758426056,
#   'ci_lower': 0.5149366502067437,
#   'ci_upper': 0.8915112206960573,
#   'p': 0.006379623713795484},
#  {'mean_activity_strata': 'mean_skew_[0.5, 1.0)',
#   'genome_region': 'is_in_CA-TF',
#   'emvar': 'emVar_HepG2',
#   'OR': 0.8320503945728922,
#   'ci_lower': 0.6313319952338629,
#   'ci_upper': 1.0965828824380357,
#   'p': 0.19899874236218723},
#  {'mean_activity_strata': 'mean_skew_[1.0, 1.5)',
#   'genome_region': 'is_in_CA-TF',
#   'emvar': 'emVar_K562',
#   'OR': 3.4257095158597664,
#   'ci_lower': 0.4653547334715528,
#   'ci_upper': 25.218365352180392,
#   'p': 0.36272224124880714},
#  {'mean_activity_strata': 'mean_skew_[1.0, 1.5)',
#   'genome_region': 'is_in_CA-TF',
#   'emvar': 'emVar_SKNSH',
#   'OR': 0.7624895920066611,
#   'ci_lower': 0.26529772885385305,
#   'ci_upper': 2.1914638335964054,
#   'p': 0.5496142102768322},
#  {'mean_activity_strata': 'mean_skew_[1.0, 1.5)',
#   'genome_region': 'is_in_CA-TF',
#   'emvar': 'emVar_HepG2',
#   'OR': 0.5078431372549019,
#   'ci_lower': 0.11770888633491165,
#   'ci_upper': 2.1910380778142526,
#   'p': 0.29040021494954554},
#  {'mean_activity_strata': 'mean_skew_(1.5, Inf)',
#   'genome_region': 'is_in_CA-TF',
#   'emvar': 'emVar_K562',
#   'OR': inf,
#   'ci_lower': nan,
#   'ci_upper': inf,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_(1.5, Inf)',
#   'genome_region': 'is_in_CA-TF',
#   'emvar': 'emVar_SKNSH',
#   'OR': inf,
#   'ci_lower': nan,
#   'ci_upper': inf,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_(1.5, Inf)',
#   'genome_region': 'is_in_CA-TF',
#   'emvar': 'emVar_HepG2',
#   'OR': inf,
#   'ci_lower': nan,
#   'ci_upper': inf,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_(-Inf, -1.5)',
#   'genome_region': 'all',
#   'emvar': 'emVar_K562',
#   'OR': 1.5361604706270544,
#   'ci_lower': 1.2092905387287434,
#   'ci_upper': 1.9513829935342435,
#   'p': 0.00023114709896537692},
#  {'mean_activity_strata': 'mean_skew_(-Inf, -1.5)',
#   'genome_region': 'all',
#   'emvar': 'emVar_SKNSH',
#   'OR': 1.0826166621184359,
#   'ci_lower': 0.6834093438065387,
#   'ci_upper': 1.7150172846162504,
#   'p': 0.8212159702266171},
#  {'mean_activity_strata': 'mean_skew_(-Inf, -1.5)',
#   'genome_region': 'all',
#   'emvar': 'emVar_HepG2',
#   'OR': 0.7339449826612966,
#   'ci_lower': 0.29704590721543417,
#   'ci_upper': 1.8134410355063861,
#   'p': 0.4252193603733497},
#  {'mean_activity_strata': 'mean_skew_[-1.5, -1.0)',
#   'genome_region': 'all',
#   'emvar': 'emVar_K562',
#   'OR': 1.8403161514055928,
#   'ci_lower': 1.7224795539990294,
#   'ci_upper': 1.9662140716047076,
#   'p': 1.936926523384328e-86},
#  {'mean_activity_strata': 'mean_skew_[-1.5, -1.0)',
#   'genome_region': 'all',
#   'emvar': 'emVar_SKNSH',
#   'OR': 1.0455612186255112,
#   'ci_lower': 0.988729235325737,
#   'ci_upper': 1.1056598943729117,
#   'p': 0.11979781509735375},
#  {'mean_activity_strata': 'mean_skew_[-1.5, -1.0)',
#   'genome_region': 'all',
#   'emvar': 'emVar_HepG2',
#   'OR': 1.0758208124086817,
#   'ci_lower': 0.9872691368732787,
#   'ci_upper': 1.1723150022466802,
#   'p': 0.09746912096592521},
#  {'mean_activity_strata': 'mean_skew_[-1.0, -0.5)',
#   'genome_region': 'all',
#   'emvar': 'emVar_K562',
#   'OR': 1.6556952283097879,
#   'ci_lower': 1.631060728075033,
#   'ci_upper': 1.680701792313457,
#   'p': 0.0},
#  {'mean_activity_strata': 'mean_skew_[-1.0, -0.5)',
#   'genome_region': 'all',
#   'emvar': 'emVar_SKNSH',
#   'OR': 1.2182003692273786,
#   'ci_lower': 1.2015134129517395,
#   'ci_upper': 1.2351190786459652,
#   'p': 2.266515413866078e-175},
#  {'mean_activity_strata': 'mean_skew_[-1.0, -0.5)',
#   'genome_region': 'all',
#   'emvar': 'emVar_HepG2',
#   'OR': 1.2372195979740477,
#   'ci_lower': 1.220437321542332,
#   'ci_upper': 1.2542326480778387,
#   'p': 2.9742953561875282e-207},
#  {'mean_activity_strata': 'mean_skew_[-0.5, -0.2)',
#   'genome_region': 'all',
#   'emvar': 'emVar_K562',
#   'OR': 1.4363284831746153,
#   'ci_lower': 1.4209092944752395,
#   'ci_upper': 1.4519149952781463,
#   'p': 0.0},
#  {'mean_activity_strata': 'mean_skew_[-0.5, -0.2)',
#   'genome_region': 'all',
#   'emvar': 'emVar_SKNSH',
#   'OR': 1.4801271560499754,
#   'ci_lower': 1.458835883558235,
#   'ci_upper': 1.5017291682825098,
#   'p': 0.0},
#  {'mean_activity_strata': 'mean_skew_[-0.5, -0.2)',
#   'genome_region': 'all',
#   'emvar': 'emVar_HepG2',
#   'OR': 1.701917919412266,
#   'ci_lower': 1.6696350112385623,
#   'ci_upper': 1.7348250275776662,
#   'p': 0.0},
#  {'mean_activity_strata': 'mean_skew_[-0.2, -0.05)',
#   'genome_region': 'all',
#   'emvar': 'emVar_K562',
#   'OR': 1.1834836273707419,
#   'ci_lower': 1.1429627756711624,
#   'ci_upper': 1.2254410432851925,
#   'p': 2.4292949385453573e-20},
#  {'mean_activity_strata': 'mean_skew_[-0.2, -0.05)',
#   'genome_region': 'all',
#   'emvar': 'emVar_SKNSH',
#   'OR': 1.6285934448931698,
#   'ci_lower': 1.4625873559315448,
#   'ci_upper': 1.8134415000871522,
#   'p': 1.2277665017353028e-16},
#  {'mean_activity_strata': 'mean_skew_[-0.2, -0.05)',
#   'genome_region': 'all',
#   'emvar': 'emVar_HepG2',
#   'OR': 2.7475159590124116,
#   'ci_lower': 2.6085662936474923,
#   'ci_upper': 2.893867011703403,
#   'p': 8.560936408360625e-242},
#  {'mean_activity_strata': 'mean_skew_[-0.05, -0.02)',
#   'genome_region': 'all',
#   'emvar': 'emVar_K562',
#   'OR': 1.1042711883390754,
#   'ci_lower': 0.8891988553267097,
#   'ci_upper': 1.3713635033276736,
#   'p': 0.35396217073995384},
#  {'mean_activity_strata': 'mean_skew_[-0.05, -0.02)',
#   'genome_region': 'all',
#   'emvar': 'emVar_SKNSH',
#   'OR': 1.173739720167225,
#   'ci_lower': 0.7608012745741312,
#   'ci_upper': 1.8108078636821454,
#   'p': 0.4718981162155462},
#  {'mean_activity_strata': 'mean_skew_[-0.05, -0.02)',
#   'genome_region': 'all',
#   'emvar': 'emVar_HepG2',
#   'OR': 3.739389122565405,
#   'ci_lower': 2.5580912154315096,
#   'ci_upper': 5.466197188594681,
#   'p': 8.228675228900266e-09},
#  {'mean_activity_strata': 'mean_skew_[-0.02, 0)',
#   'genome_region': 'all',
#   'emvar': 'emVar_K562',
#   'OR': 1.2457132183345825,
#   'ci_lower': 0.9405259103526047,
#   'ci_upper': 1.6499294758947471,
#   'p': 0.12972330024259077},
#  {'mean_activity_strata': 'mean_skew_[-0.02, 0)',
#   'genome_region': 'all',
#   'emvar': 'emVar_SKNSH',
#   'OR': 1.6535665491643767,
#   'ci_lower': 1.0190273398973082,
#   'ci_upper': 2.68322764803438,
#   'p': 0.05698583408271553},
#  {'mean_activity_strata': 'mean_skew_[-0.02, 0)',
#   'genome_region': 'all',
#   'emvar': 'emVar_HepG2',
#   'OR': 2.6381919185657647,
#   'ci_lower': 1.5078211765775156,
#   'ci_upper': 4.615969524306452,
#   'p': 0.0021147088846357417},
#  {'mean_activity_strata': 'mean_skew_[0, 0.02)',
#   'genome_region': 'all',
#   'emvar': 'emVar_K562',
#   'OR': 1.0565888501852505,
#   'ci_lower': 0.7752716524410996,
#   'ci_upper': 1.4399855777270347,
#   'p': 0.6851823209394717},
#  {'mean_activity_strata': 'mean_skew_[0, 0.02)',
#   'genome_region': 'all',
#   'emvar': 'emVar_SKNSH',
#   'OR': 0.9921000163597319,
#   'ci_lower': 0.5126048759512026,
#   'ci_upper': 1.9201191573423058,
#   'p': 1.0},
#  {'mean_activity_strata': 'mean_skew_[0, 0.02)',
#   'genome_region': 'all',
#   'emvar': 'emVar_HepG2',
#   'OR': 3.9875037264022914,
#   'ci_lower': 2.4635940752298557,
#   'ci_upper': 6.45406080812589,
#   'p': 2.143910765480269e-06},
#  {'mean_activity_strata': 'mean_skew_[0.02, 0.05)',
#   'genome_region': 'all',
#   'emvar': 'emVar_K562',
#   'OR': 1.199755001971527,
#   'ci_lower': 0.9684564662958146,
#   'ci_upper': 1.4862950631753347,
#   'p': 0.09520599970149461},
#  {'mean_activity_strata': 'mean_skew_[0.02, 0.05)',
#   'genome_region': 'all',
#   'emvar': 'emVar_SKNSH',
#   'OR': 1.6406528829232072,
#   'ci_lower': 1.0821857026270127,
#   'ci_upper': 2.4873197601021806,
#   'p': 0.030113897896106474},
#  {'mean_activity_strata': 'mean_skew_[0.02, 0.05)',
#   'genome_region': 'all',
#   'emvar': 'emVar_HepG2',
#   'OR': 2.3410129895944203,
#   'ci_lower': 1.4759729246416662,
#   'ci_upper': 3.7130368219866305,
#   'p': 0.001136772225814508},
#  {'mean_activity_strata': 'mean_skew_[0.05, 0.2)',
#   'genome_region': 'all',
#   'emvar': 'emVar_K562',
#   'OR': 1.1633422838697671,
#   'ci_lower': 1.122014120102048,
#   'ci_upper': 1.206192725378747,
#   'p': 1.1337535954231058e-15},
#  {'mean_activity_strata': 'mean_skew_[0.05, 0.2)',
#   'genome_region': 'all',
#   'emvar': 'emVar_SKNSH',
#   'OR': 1.9057447970081522,
#   'ci_lower': 1.6915667644208108,
#   'ci_upper': 2.1470410200257075,
#   'p': 4.072248267172726e-22},
#  {'mean_activity_strata': 'mean_skew_[0.05, 0.2)',
#   'genome_region': 'all',
#   'emvar': 'emVar_HepG2',
#   'OR': 1.7855256345361346,
#   'ci_lower': 1.6706294695018102,
#   'ci_upper': 1.9083236886371775,
#   'p': 1.7239677469749927e-55},
#  {'mean_activity_strata': 'mean_skew_[0.2, 0.5)',
#   'genome_region': 'all',
#   'emvar': 'emVar_K562',
#   'OR': 1.1573459771304067,
#   'ci_lower': 1.141756599996999,
#   'ci_upper': 1.173148209332406,
#   'p': 1.5459733746084433e-95},
#  {'mean_activity_strata': 'mean_skew_[0.2, 0.5)',
#   'genome_region': 'all',
#   'emvar': 'emVar_SKNSH',
#   'OR': 1.3420548867392048,
#   'ci_lower': 1.3205067831841837,
#   'ci_upper': 1.3639546134534029,
#   'p': 3.1554903832270998e-257},
#  {'mean_activity_strata': 'mean_skew_[0.2, 0.5)',
#   'genome_region': 'all',
#   'emvar': 'emVar_HepG2',
#   'OR': 1.3231150167765415,
#   'ci_lower': 1.2933991311425739,
#   'ci_upper': 1.3535136258156433,
#   'p': 3.0102425241155896e-119},
#  {'mean_activity_strata': 'mean_skew_[0.5, 1.0)',
#   'genome_region': 'all',
#   'emvar': 'emVar_K562',
#   'OR': 1.2464238132961025,
#   'ci_lower': 1.2245561670035157,
#   'ci_upper': 1.2686819634849278,
#   'p': 8.282068810663375e-133},
#  {'mean_activity_strata': 'mean_skew_[0.5, 1.0)',
#   'genome_region': 'all',
#   'emvar': 'emVar_SKNSH',
#   'OR': 1.3230496933953615,
#   'ci_lower': 1.2993597102562038,
#   'ci_upper': 1.3471715933445476,
#   'p': 8.44770493580619e-207},
#  {'mean_activity_strata': 'mean_skew_[0.5, 1.0)',
#   'genome_region': 'all',
#   'emvar': 'emVar_HepG2',
#   'OR': 1.1429073743616467,
#   'ci_lower': 1.122966120583151,
#   'ci_upper': 1.1632027382018528,
#   'p': 2.611423607837206e-50},
#  {'mean_activity_strata': 'mean_skew_[1.0, 1.5)',
#   'genome_region': 'all',
#   'emvar': 'emVar_K562',
#   'OR': 1.3269017871743458,
#   'ci_lower': 1.2322823816209099,
#   'ci_upper': 1.428786436506979,
#   'p': 9.426223409961441e-15},
#  {'mean_activity_strata': 'mean_skew_[1.0, 1.5)',
#   'genome_region': 'all',
#   'emvar': 'emVar_SKNSH',
#   'OR': 1.5259856344109632,
#   'ci_lower': 1.3883156897738103,
#   'ci_upper': 1.6773073830261325,
#   'p': 1.6693804466064644e-20},
#  {'mean_activity_strata': 'mean_skew_[1.0, 1.5)',
#   'genome_region': 'all',
#   'emvar': 'emVar_HepG2',
#   'OR': 1.5185854889296564,
#   'ci_lower': 1.3279178619383791,
#   'ci_upper': 1.7366299176226727,
#   'p': 9.801955266488913e-11},
#  {'mean_activity_strata': 'mean_skew_(1.5, Inf)',
#   'genome_region': 'all',
#   'emvar': 'emVar_K562',
#   'OR': 2.782822871316502,
#   'ci_lower': 2.0396570546228436,
#   'ci_upper': 3.7967672631878764,
#   'p': 3.957960732954183e-14},
#  {'mean_activity_strata': 'mean_skew_(1.5, Inf)',
#   'genome_region': 'all',
#   'emvar': 'emVar_SKNSH',
#   'OR': 2.7471030566832684,
#   'ci_lower': 1.1362046646503554,
#   'ci_upper': 6.641915351017208,
#   'p': 0.016648422768239197},
#  {'mean_activity_strata': 'mean_skew_(1.5, Inf)',
#   'genome_region': 'all',
#   'emvar': 'emVar_HepG2',
#   'OR': inf,
#   'ci_lower': nan,
#   'ci_upper': inf,
#   'p': 0.07930247158054735}]
