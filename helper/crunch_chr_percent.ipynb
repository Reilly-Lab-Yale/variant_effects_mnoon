# %%
# !wget https://hgdownload.cse.ucsc.edu/goldenpath/hg38/bigZips/hg38.chrom.sizes
# Out:
# --2023-12-19 11:40:41--  https://hgdownload.cse.ucsc.edu/goldenpath/hg38/bigZips/hg38.chrom.sizes
# Resolving hgdownload.cse.ucsc.edu (hgdownload.cse.ucsc.edu)... 128.114.119.163
# Connecting to hgdownload.cse.ucsc.edu (hgdownload.cse.ucsc.edu)|128.114.119.163|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11672 (11K)
# Saving to: ‘hg38.chrom.sizes.1’
#
# hg38.chrom.sizes.1  100%[===================>]  11.40K  --.-KB/s    in 0.07s
#
# 2023-12-19 11:40:41 (154 KB/s) - ‘hg38.chrom.sizes.1’ saved [11672/11672]

# %%
cat hg38.chrom.sizes | grep -v _ | grep -v "M" | grep -v "Y"  > regular_chromosomes

# %%
cat regular_chromosomes
# Out:
# chr1	248956422
# chr2	242193529
# chr3	198295559
# chr4	190214555
# chr5	181538259
# chr6	170805979
# chr7	159345973
# chrX	156040895
# chr8	145138636
# chr9	138394717
# chr11	135086622
# chr10	133797422
# chr12	133275309
# chr13	114364328
# chr14	107043718
# chr15	101991189
# chr16	90338345
# chr17	83257441
# chr18	80373285
# chr20	64444167
# chr19	58617616
# chr22	50818468
# chr21	46709983

# %%
import pandas as pd
chrs=pd.read_csv("regular_chromosomes",delimiter="\t",header=None)
chrs.columns=["chr","len"]
chrs["perc"]=chrs["len"]/chrs["len"].sum()*100
chrs
# Out:
#       chr        len      perc
# 0    chr1  248956422  8.213558
# 1    chr2  242193529  7.990437
# 2    chr3  198295559  6.542157
# 3    chr4  190214555  6.275549
# 4    chr5  181538259  5.989301
# 5    chr6  170805979  5.635222
# 6    chr7  159345973  5.257134
# 7    chrX  156040895  5.148093
# 8    chr8  145138636  4.788407
# 9    chr9  138394717  4.565912
# 10  chr11  135086622  4.456771
# 11  chr10  133797422  4.414238
# 12  chr12  133275309  4.397012
# 13  chr13  114364328  3.773102
# 14  chr14  107043718  3.531581
# 15  chr15  101991189  3.364888
# 16  chr16   90338345  2.980438
# 17  chr17   83257441  2.746825
# 18  chr18   80373285  2.651671
# 19  chr20   64444167  2.126139
# 20  chr19   58617616  1.933909
# 21  chr22   50818468  1.676600
# 22  chr21   46709983  1.541053
